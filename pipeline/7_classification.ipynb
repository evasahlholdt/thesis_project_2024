# %% [markdown]
# # **Utility evaluation using classification task**

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
## Append parent directory
sys.path.append(os.path.dirname(os.getcwd()))
from model_classification.model import ShallowConvNet
from model_classification.loader import load_data
from model_classification.run_classification import classify

# %% [markdown]
# ## **Synthetic data**

# %% [markdown]
# ### **3-SUB** Real data only

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="real_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True
)

# %% [markdown]
# ### **3-SUB** Synthetic data only

# %%
classify(
    train_feature_path="/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_25_sub_3_channels_dropout_0",
    use_cpu = True,
    preprocessing=True
)

# %% [markdown]
# ### **3-SUB** 10 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_10%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_10%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_10%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_10%_25_sub_3_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_10%_25_sub_3_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **3-SUB** 50 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_50%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_50%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_50%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_50%_25_sub_3_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_50%_25_sub_3_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **3-SUB** 100 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="syn_100%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_3_channels.npy",
    augment_percentage = 100
)

# %% [markdown]
# ### **15-SUB** Real data only

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="real_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True
)

# %% [markdown]
# ### **15-SUB** Synthetic data only

# %%
classify(
    train_feature_path="/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_25_sub_15_channels_dropout_0",
    use_cpu = True,
    preprocessing=True
)

# %% [markdown]
# ### **15-SUB** 10 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_10%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_10%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_10%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_10%_25_sub_15_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_10%_25_sub_15_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **15-SUB** 50 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_50%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_50%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_50%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_50%_25_sub_15_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_50%_25_sub_15_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **15-SUB** 100 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="syn_100%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/25_sub/synthetic_features_25_sub_15_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/25_sub/synthetic_attributes_25_sub_15_channels.npy",
    augment_percentage = 100
)

# %% [markdown]
# ### **3-ALL** Real data only

# %%
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="real_all_sub_3_channels_dropout_0", 
    use_cpu=True,
    preprocessing=True
)

# %% [markdown]
# ### **3-ALL** Synthetic data only

# %%
classify(
    train_feature_path="/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_all_sub_3_channels_dropout_0", 
    use_cpu = True,
    preprocessing=True
)

# %% [markdown]
# ###  **3-ALL** 10 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_10%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_10%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_10%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_10%_all_sub_3_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_10%_all_sub_3_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **3-ALL** 50 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_50%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_50%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_50%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_50%_all_sub_3_channels_dropout_0_4",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_50%_all_sub_3_channels_dropout_0_5",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **3-ALL** 100 % synthetic, 100 % real

# %%
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="syn_100%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = False,
    augment_feature_path = "/work/GAN/data_synthetic/synthetic_features_all_sub_3_channels.npy", 
    augment_attribute_path="/work/GAN/data_synthetic/synthetic_attributes_all_sub_3_channels.npy",
    augment_percentage = 100
)

# %% [markdown]
# # **Baselines**

# %% [markdown]
# ###  **Baseline 3-ALL** Pure baseline

# %%
# Moderate 
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)   

# High
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)

# %% [markdown]
# ### **Baseline 3-ALL** 10 % baseline, 100 % real

# %%
# Moderate 

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

# High
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_10%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_10%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_10%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **Baseline 3-ALL** 50 % baseline, 100 % real

# %%
# # Moderate
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   
    
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   
    
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   
    

# High
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_50%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_50%_all_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_50%_all_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **Baseline 3-ALL** 100 % baseline, 100 % real

# %%
# Moderate
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="moderate_baseline_100%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 100
)   
    

# High
classify(
    train_feature_path="/work/GAN/data_real/all_sub/train_features_all_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/all_sub/test_features_all_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/all_sub/test_attributes_all_sub_3_channels.npy",
    dataset_name="high_baseline_100%_all_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_all_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/all_sub/train_attributes_all_sub_3_channels.npy",
    augment_percentage = 100
)

# %% [markdown]
# ### **Baseline 3-SUB** Pure baseline

# %%
# Moderate 
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)   

# High
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)

# %% [markdown]
# ### **Baseline 3-SUB** 10 % baseline, 100 % real

# %%
# Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

# High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_10%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_10%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_10%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **Baseline 3-SUB** 50 % synthetic, 100 % real

# %%
# Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   


# High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_50%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_50%_25_sub_3_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_50%_25_sub_3_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **Baseline 3-SUB** 100 % synthetic, 100 % real

# %%
# # Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="moderate_baseline_100%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 100
)   

# High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_3_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_3_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_3_channels.npy",
    dataset_name="high_baseline_100%_25_sub_3_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_3_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_3_channels.npy",
    augment_percentage = 100
)

# %% [markdown]
# ### **Baseline 15-SUB** Pure baseline

# %%
# Moderate 
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)   

# High
classify(
    train_feature_path="/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    is_baseline = True
)

# %% [markdown]
# ### **Baseline 15-SUB** 10 % baseline, 100 % real

# %%
#Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_10%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

#High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_10%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_10%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_10%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 10
)

# %% [markdown]
# ### **Baseline 15-SUB** 50 % baseline, 100 % real

# %%
# Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_50%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

# High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_50%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_50%_25_sub_15_channels_dropout_0_2",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)   

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_50%_25_sub_15_channels_dropout_0_3",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 50
)

# %% [markdown]
# ### **Baseline 15-SUB** 100 % baseline, 100 % real

# %%
´
# Moderate 

classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="moderate_baseline_100%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_moderate.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 100
)   

# High
classify(
    train_feature_path="/work/GAN/data_real/25_sub/train_features_25_sub_15_channels.npy",
    train_attribute_path="/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    test_feature_path="/work/GAN/data_real/25_sub/test_features_25_sub_15_channels.npy",
    test_attribute_path="/work/GAN/data_real/25_sub/test_attributes_25_sub_15_channels.npy",
    dataset_name="high_baseline_100%_25_sub_15_channels_dropout_0",
    use_cpu=True,
    preprocessing=True,
    use_augmentation = True,
    is_baseline = True,
    augment_feature_path = "/work/GAN/data_synthetic/baseline/train_features_25_sub_15_channels_high.npy",
    augment_attribute_path = "/work/GAN/data_real/25_sub/train_attributes_25_sub_15_channels.npy",
    augment_percentage = 100
)
