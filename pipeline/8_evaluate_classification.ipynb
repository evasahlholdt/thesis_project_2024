# %% [markdown]
# # **Evaluate classification models**

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
## Append parent directory
sys.path.append(os.path.dirname(os.getcwd()))
import openpyxl
import numpy as np
import pickle
import json
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Callable, Dict, List, Optional, Tuple
import matplotlib.colors as mcolors
from scripts.plots import plot_confusion_matrices, plot_classification_results

# %% [markdown]
# # Confusion matrices

# %%
plot_confusion_matrices("/work/GAN/results/results_classification", condition="real")
plot_confusion_matrices("/work/GAN/results/results_classification", condition="syn")
plot_confusion_matrices("/work/GAN/results/results_classification", condition="high_baseline")
plot_confusion_matrices("/work/GAN/results/results_classification", condition="moderate_baseline")

plot_confusion_matrices("/work/GAN/results/results_classification", condition="syn", augment_percentage=10)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="high_baseline", augment_percentage=10)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="moderate_baseline", augment_percentage=10)

plot_confusion_matrices("/work/GAN/results/results_classification", condition="syn", augment_percentage=50)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="high_baseline", augment_percentage=50)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="moderate_baseline", augment_percentage=50)

plot_confusion_matrices("/work/GAN/results/results_classification", condition="syn", augment_percentage=100)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="high_baseline", augment_percentage=100)
plot_confusion_matrices("/work/GAN/results/results_classification", condition="moderate_baseline", augment_percentage=100)

# %% [markdown]
# # Table of all classification results

# %%
plot_classification_results("/work/GAN/results/results_classification", "/work/GAN/results/results_classification/results_table")
# Out:
#                                                     Accuracy %  \
# High baseline data, 10% augmentation, 25 subjec...        70.5
# High baseline data, 10% augmentation, 25 subjec...        47.3
# High baseline data, 10% augmentation, all subje...        65.4
# High baseline data, 100% augmentation, 25 subje...        69.6
# High baseline data, 100% augmentation, 25 subje...        64.3
# High baseline data, 100% augmentation, all subj...        59.9
# High baseline data, 25 subjects, 15 channels              41.1
# High baseline data, 25 subjects, 3 channels               45.5
# High baseline data, 50% augmentation, 25 subjec...        61.6
# High baseline data, 50% augmentation, 25 subjec...        58.9
# High baseline data, 50% augmentation, all subje...        56.8
# High baseline data, all subjects, 3 channels              53.3
# Moderate baseline data, 10% augmentation, 25 su...        70.5
# Moderate baseline data, 10% augmentation, 25 su...        60.7
# ...
